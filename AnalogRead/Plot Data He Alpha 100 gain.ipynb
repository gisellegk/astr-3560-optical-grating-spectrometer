# %%
import numpy as np
from numpy import linalg as LA
from numpy import random
from scipy import linalg as sp_LA
import matplotlib.pyplot as plt

f = open('dark_ambient.csv', 'r')
data = np.loadtxt(f, delimiter=",").transpose()[:, 0:1600]

print("Imported Data")
print(data.shape)
# Out:
# Imported Data
# (2, 1226)

# %%
fig = plt.figure(figsize=(12,4), dpi=80)

plt.plot(data[1], data[0], c='r',marker='o', alpha=0.5)
plt.xlabel("time (s)")
plt.ylabel("voltage (V)")
# Out:
# Text(0, 0.5, 'voltage (V)')

# %%
print("dark conditions (ambient room)")
mean = np.mean(data[0])
print("mean: ", mean)
std = np.std(data[0])
print("std: ", std)
# Out:
# dark conditions (ambient room)
# mean:  0.24959977732463293
# std:  0.00224095799657696

# %%
# max around .30
# gain = 1000 * 69.8
# Current =
