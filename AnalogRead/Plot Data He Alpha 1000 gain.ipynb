# %%
import numpy as np
from numpy import linalg as LA
from numpy import random
from scipy import linalg as sp_LA
import matplotlib.pyplot as plt

f = open('h_alpha.csv', 'r') #h-alpha sampled @ ~200 Hz
data = np.loadtxt(f, delimiter=",").transpose()[:, 800:]

print("Imported Data")
print(data.shape)
# Out:
# Imported Data
# (2, 1727)

# %%
fig = plt.figure(figsize=(12,4), dpi=80)

plt.plot(data[1], data[0], c='r',marker='o', alpha=0.5)
plt.xlabel("time (s)")
plt.ylabel("voltage (V)")
# Out:
# Text(0, 0.5, 'voltage (V)')

# %%
print("Hand blocking Ha line")
mean = np.mean(data[0])
print("mean: ", mean)
std = np.std(data[0])
print("std: ", std)
#Unit = Volts
# Out:
# Hand blocking Ha line
# mean:  0.2349183333333333
# std:  0.0012449543052747841
